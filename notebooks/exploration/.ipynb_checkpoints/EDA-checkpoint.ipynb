# %% [markdown]
# # EDA

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

np.random.seed(29)

# %%
data = pd.read_csv('../../data/raw/ACME-HappinessSurvey2020.csv')

# %%
data.describe()
# Out:
#                 Y          X1          X2          X3          X4          X5  \
# count  126.000000  126.000000  126.000000  126.000000  126.000000  126.000000
# mean     0.547619    4.333333    2.531746    3.309524    3.746032    3.650794
# std      0.499714    0.800000    1.114892    1.023440    0.875776    1.147641
# min      0.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      0.000000    4.000000    2.000000    3.000000    3.000000    3.000000
# 50%      1.000000    5.000000    3.000000    3.000000    4.000000    4.000000
# 75%      1.000000    5.000000    3.000000    4.000000    4.000000    4.000000
# max      1.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#                X6
# count  126.000000
# mean     4.253968
# std      0.809311
# min      1.000000
# 25%      4.000000
# 50%      4.000000
# 75%      5.000000
# max      5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Y       126 non-null    int64
#  1   X1      126 non-null    int64
#  2   X2      126 non-null    int64
#  3   X3      126 non-null    int64
#  4   X4      126 non-null    int64
#  5   X5      126 non-null    int64
#  6   X6      126 non-null    int64
# dtypes: int64(7)
# memory usage: 7.0 KB

# %%
corr = data.corr()
sns.heatmap(corr, cmap='coolwarm', center=0, annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
data['Y'].value_counts(normalize=True)
# Out:
# Y
# 1    0.547619
# 0    0.452381
# Name: proportion, dtype: float64

# %% [markdown]
# ### Histograms
#
# Creates histograms for each feature (i.e. each survey question), showing how many customers gave each score for the question and the average score across all customers (shown by the red line).

# %%
bins = np.arange(0.5, 6.5, 1)
xticks = range(1, 6)

on_time = data['X1']
mean = np.mean(on_time)
plt.hist(on_time, bins=bins, color='darkblue')
plt.axvline(mean, color='red', linestyle='--', linewidth=2, label='Mean')
plt.xticks(xticks)
plt.title('Was My Order Delivered on Time?')
plt.xlabel('Happiness')
plt.ylabel('Number of Reponses')
plt.legend(loc='upper left')
plt.show()

contents = data['X2']
mean = np.mean(contents)
plt.hist(contents, bins=bins, color='darkgreen')
plt.axvline(mean, color='red', linestyle='--', linewidth=2, label='Mean')
plt.xticks(xticks)
plt.title('Contents of My Order was as Expected')
plt.xlabel('Happiness')
plt.ylabel('Number of Reponses')
plt.legend(loc='upper left')
plt.show()

everything_available = data['X3']
mean = np.mean(everything_available)
plt.hist(everything_available, bins=bins, color='gold')
plt.axvline(mean, color='red', linestyle='--', linewidth=2, label='Mean')
plt.xticks(xticks)
plt.title('I Ordered Everything I Wanted to Order')
plt.xlabel('Happiness')
plt.ylabel('Number of Reponses')
plt.legend(loc='upper left')
plt.show()

price = data['X4']
mean = np.mean(price)
plt.hist(price, bins=bins, color='mediumorchid')
plt.axvline(mean, color='red', linestyle='--', linewidth=2, label='Mean')
plt.xticks(xticks)
plt.title('I Paid a Good Price')
plt.xlabel('Happiness')
plt.ylabel('Number of Reponses')
plt.legend(loc='upper left')
plt.show()

courier = data['X5']
mean = np.mean(courier)
plt.hist(courier, bins=bins, color='lightskyblue')
plt.axvline(mean, color='red', linestyle='--', linewidth=2, label='Mean')
plt.xticks(xticks)
plt.title('I Am Satisfied with my Courier')
plt.xlabel('Happiness')
plt.ylabel('Number of Reponses')
plt.legend(loc='upper left')
plt.show()

app = data['X6']
mean = np.mean(app)
plt.hist(app, bins=bins, color='springgreen')
plt.axvline(mean, color='red', linestyle='--', linewidth=2, label='Mean')
plt.xticks(xticks)
plt.title('The App Makes Ordering Easy for Me')
plt.xlabel('Happiness')
plt.ylabel('Number of Reponses')
plt.legend(loc='upper left')
plt.show()

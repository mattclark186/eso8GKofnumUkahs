# %%
import os
os.chdir(r"C:\Users\mattc\OneDrive\Documents\eso8GKofnumUkahs")
os.getcwd()
# Out:
# 'C:\\Users\\mattc\\OneDrive\\Documents\\eso8GKofnumUkahs'

# %%
import numpy as np
import pandas as pd
from lazypredict.Supervised import LazyClassifier

from src.data.prepare_data import x_y_split, tt_split

# %%
data = pd.read_csv('data/raw/ACME-HappinessSurvey2020.csv')

x, y = x_y_split(data)

x_train, x_test, y_train, y_test = tt_split(x, y)

# %%
lzclf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = lzclf.fit(x_train, x_test, y_train, y_test)

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy   ROC AUC  \
# Model
# PassiveAggressiveClassifier    0.615385           0.601190  0.654762
# XGBClassifier                  0.615385           0.595238  0.505952
# QuadraticDiscriminantAnalysis  0.576923           0.571429  0.613095
# KNeighborsClassifier           0.576923           0.565476  0.529762
# ExtraTreeClassifier            0.576923           0.559524  0.562500
# ExtraTreesClassifier           0.576923           0.559524  0.577381
# RidgeClassifier                0.538462           0.529762  0.529762
# LogisticRegression             0.538462           0.529762  0.535714
# LinearDiscriminantAnalysis     0.538462           0.529762  0.529762
# LinearSVC                      0.538462           0.529762  0.523810
# BernoulliNB                    0.538462           0.529762  0.607143
# GaussianNB                     0.538462           0.523810  0.619048
# CalibratedClassifierCV         0.538462           0.523810  0.511905
# RidgeClassifierCV              0.538462           0.523810  0.523810
# SGDClassifier                  0.538462           0.523810  0.690476
# RandomForestClassifier         0.538462           0.517857  0.508929
# DummyClassifier                0.538462           0.500000  0.500000
# BaggingClassifier              0.500000           0.494048  0.526786
# NearestCentroid                0.500000           0.494048  0.625000
# LabelSpreading                 0.500000           0.488095  0.613095
# NuSVC                          0.500000           0.488095  0.500000
# LabelPropagation               0.500000           0.482143  0.595238
# AdaBoostClassifier             0.500000           0.476190  0.494048
# DecisionTreeClassifier         0.461538           0.452381  0.470238
# SVC                            0.461538           0.446429  0.476190
# Perceptron                     0.423077           0.404762  0.464286
#
#                                F1 Score  Precision    Recall  Time Taken
# Model
# PassiveAggressiveClassifier    0.600962   0.617521  0.615385    0.035401
# XGBClassifier                  0.585219   0.630769  0.615385    0.185837
# QuadraticDiscriminantAnalysis  0.575020   0.574825  0.576923    0.028690
# KNeighborsClassifier           0.567175   0.573152  0.576923    0.047662
# ExtraTreeClassifier            0.553306   0.575477  0.576923    0.024572
# ExtraTreesClassifier           0.553306   0.575477  0.576923    0.217674
# RidgeClassifier                0.532867   0.533654  0.538462    0.033246
# LogisticRegression             0.532867   0.533654  0.538462    0.032943
# LinearDiscriminantAnalysis     0.532867   0.533654  0.538462    0.042353
# LinearSVC                      0.532867   0.533654  0.538462    0.025846
# BernoulliNB                    0.532867   0.533654  0.538462    0.048856
# GaussianNB                     0.521154   0.529915  0.538462    0.034940
# CalibratedClassifierCV         0.521154   0.529915  0.538462    0.123808
# RidgeClassifierCV              0.521154   0.529915  0.538462    0.031838
# SGDClassifier                  0.521154   0.529915  0.538462    0.029556
# RandomForestClassifier         0.502262   0.526923  0.538462    0.220741
# DummyClassifier                0.376923   0.289941  0.538462    0.031329
# BaggingClassifier              0.497751   0.496970  0.500000    0.074055
# NearestCentroid                0.497751   0.496970  0.500000    0.035701
# LabelSpreading                 0.488479   0.490196  0.500000    0.027364
# NuSVC                          0.488479   0.490196  0.500000    0.032878
# LabelPropagation               0.472089   0.481203  0.500000    0.032286
# AdaBoostClassifier             0.447059   0.466667  0.500000    0.303823
# DecisionTreeClassifier         0.455012   0.453846  0.461538    0.029862
# SVC                            0.441346   0.442308  0.461538    0.030138
# Perceptron                     0.390872   0.386929  0.423077    0.027736

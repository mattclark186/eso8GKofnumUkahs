# %%
import os
os.chdir(r"C:\Users\mattc\OneDrive\Documents\eso8GKofnumUkahs")
os.getcwd()
# Out:
# 'C:\\Users\\mattc\\OneDrive\\Documents\\eso8GKofnumUkahs'

# %%
import numpy as np
import pandas as pd
from IPython.display import display, Markdown
from matplotlib import pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score, classification_report, make_scorer

from src.data.prepare_data import x_y_split, tt_split

# %%
np.random.seed(29)

# %%
data = pd.read_csv('data/raw/ACME-HappinessSurvey2020.csv')

x, y = x_y_split(data)

# x_train, x_test, y_train, y_test = tt_split(x, y)

# %%
sss = StratifiedShuffleSplit(
    n_splits=10,
    test_size=0.2, 
    random_state=29
)

param_grid = {
    'n_neighbors': [1, 2, 3, 5, 7, 10, 12, 15, 20],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

test_accuracies = []
cv_accuracies = []

for train_index, test_index in sss.split(x, y):
    x_train = x.iloc[train_index]
    x_test = x.iloc[test_index]
    y_train = y.iloc[train_index]
    y_test = y.iloc[test_index]

    knn_grid = GridSearchCV(
        KNeighborsClassifier(),
        param_grid,
        cv=5, 
        scoring='balanced_accuracy',
        n_jobs=-1
    )

    knn_grid.fit(x_train, y_train)
    knn_model = knn_grid.best_estimator_

    y_pred = knn_model.predict(x_test)

    test_accuracies.append(accuracy_score(y_test, y_pred))
    cv_accuracies.append(knn_grid.best_score_)

    print('Best Parameters:')
    print(knn_grid.best_params_)

print('Mean CV accuracy:')
print(round(np.mean(cv_accuracies), 3))

print('\nMean test accuracy:')
print(round(np.mean(test_accuracies), 3))

print('\nTest accuracy standard deviation:')
print(round(np.std(test_accuracies), 3))

print('\nIndividual test accuracies:')
print(np.round(test_accuracies, 3))
# Out:
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 12, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 2, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'euclidean', 'n_neighbors': 2, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 2, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 12, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 20, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 12, 'weights': 'distance'}
# Mean CV accuracy:
# 0.63
#
# Mean test accuracy:
# 0.538
#
# Test accuracy standard deviation:
# 0.097
#
# Individual test accuracies:
# ...

# %% [markdown]
# ### x_drop

# %%
x_drop = x.drop(columns=['X1'])

sss = StratifiedShuffleSplit(
    n_splits=10,
    test_size=0.2, 
    random_state=29
)

param_grid = {
    'n_neighbors': [1, 2, 3, 5, 7, 10, 12, 15, 20],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

test_accuracies = []
cv_accuracies = []

for train_index, test_index in sss.split(x_drop, y):
    x_train = x_drop.iloc[train_index]
    x_test = x_drop.iloc[test_index]
    y_train = y.iloc[train_index]
    y_test = y.iloc[test_index]

    knn_grid = GridSearchCV(
        KNeighborsClassifier(),
        param_grid,
        cv=5, 
        scoring='balanced_accuracy',
        n_jobs=-1
    )

    knn_grid.fit(x_train, y_train)
    knn_model = knn_grid.best_estimator_

    y_pred = knn_model.predict(x_test)

    test_accuracies.append(accuracy_score(y_test, y_pred))
    cv_accuracies.append(knn_grid.best_score_)

    print('Best Parameters:')
    print(knn_grid.best_params_)

print('Mean CV accuracy:')
print(round(np.mean(cv_accuracies), 3))

print('\nMean test accuracy:')
print(round(np.mean(test_accuracies), 3))

print('\nTest accuracy standard deviation:')
print(round(np.std(test_accuracies), 3))

print('\nIndividual test accuracies:')
print(np.round(test_accuracies, 3))
# Out:
# Best Parameters:
# {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# Best Parameters:
# {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'euclidean', 'n_neighbors': 12, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'euclidean', 'n_neighbors': 2, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 2, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 12, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'euclidean', 'n_neighbors': 12, 'weights': 'uniform'}
# Best Parameters:
# {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'uniform'}
# Mean CV accuracy:
# 0.594
#
# Mean test accuracy:
# 0.538
#
# Test accuracy standard deviation:
# 0.093
#
# Individual test accuracies:
# ...

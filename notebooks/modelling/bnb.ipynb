# %%
import os
os.chdir(r"C:\Users\mattc\OneDrive\Documents\eso8GKofnumUkahs")
os.getcwd()
# Out:
# 'C:\\Users\\mattc\\OneDrive\\Documents\\eso8GKofnumUkahs'

# %%
import numpy as np
import pandas as pd
from IPython.display import display, Markdown
from matplotlib import pyplot as plt
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score, classification_report, make_scorer

from src.data.prepare_data import x_y_split, tt_split

# %%
np.random.seed(29)

# %%
data = pd.read_csv('data/raw/ACME-HappinessSurvey2020.csv')

x, y = x_y_split(data)

# x_train, x_test, y_train, y_test = tt_split(x, y)

# %%
n = 0

sss = StratifiedShuffleSplit(
    n_splits=10, 
    test_size=0.2, 
    random_state=29
)

param_grid = {
    'alpha': [0.01, 0.1, 1],
    'binarize': [1, 2, 3, 4],
    'fit_prior': [True, False]
}

test_accuracies = []
cv_accuracies = []

for train_index, test_index in sss.split(x, y):
    x_train = x.iloc[train_index]
    x_test = x.iloc[test_index]
    y_train = y.iloc[train_index]
    y_test = y.iloc[test_index]
    
    bnb_grid = GridSearchCV(
        BernoulliNB(),
        param_grid,
        cv=3, 
        scoring='f1',
        n_jobs=-1,
        verbose=2
    )

    bnb_grid.fit(x_train, y_train)
    bnb_model = bnb_grid.best_estimator_

    y_pred = bnb_model.predict(x_test)

    test_accuracies.append(accuracy_score(y_test, y_pred))
    cv_accuracies.append(bnb_grid.best_score_)

    n += 1
    print(n)
    
    print('Best Parameters:')
    print(bnb_grid.best_params_)

print('Mean CV accuracy:')
print(round(np.mean(cv_accuracies), 3))

print('\nMean test accuracy:')
print(round(np.mean(test_accuracies), 3))

print('\nTest accuracy standard deviation:')
print(round(np.std(test_accuracies), 3))

print('\nIndividual test accuracies:')
print(np.round(test_accuracies, 3))
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 1
# Best Parameters:
# {'alpha': 0.01, 'binarize': 4, 'fit_prior': True}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 2
# Best Parameters:
# {'alpha': 0.01, 'binarize': 4, 'fit_prior': True}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 3
# Best Parameters:
# {'alpha': 0.01, 'binarize': 1, 'fit_prior': True}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 4
# Best Parameters:
# {'alpha': 0.01, 'binarize': 2, 'fit_prior': True}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 5
# Best Parameters:
# {'alpha': 0.01, 'binarize': 1, 'fit_prior': True}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 6
# Best Parameters:
# {'alpha': 1, 'binarize': 1, 'fit_prior': True}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 7
# Best Parameters:
# {'alpha': 1, 'binarize': 4, 'fit_prior': True}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 8
# Best Parameters:
# {'alpha': 0.1, 'binarize': 1, 'fit_prior': True}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 9
# Best Parameters:
# {'alpha': 0.01, 'binarize': 2, 'fit_prior': True}
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# 10
# Best Parameters:
# {'alpha': 0.01, 'binarize': 1, 'fit_prior': True}
# Mean CV accuracy:
# 0.691
#
# Mean test accuracy:
# 0.531
#
# Test accuracy standard deviation:
# 0.045
#
# Individual test accuracies:
# [0.5   0.577 0.577 0.577 0.538 0.5   0.462 0.577 0.462 0.538]
